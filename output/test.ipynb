# %%
import pandas as pd

# %%
df = pd.read_csv('data1.csv')
df.head()
# Out:
#                     email                                                url
# 0  corporateask@gmail.com  https://bd.linkedin.com/in/md-mahabubul-kabir-...
# 1  faysalahmedp@gmail.com  https://bd.linkedin.com/in/faysal-ahmed-prodip...
# 2  asifarefin23@gmail.com   https://bd.linkedin.com/in/asif-arefin-53523b13a
# 3       ahad2k8@gmail.com  https://bd.linkedin.com/in/md-abdul-ahad-emran...
# 4    rokontamal@gmail.com  https://bd.linkedin.com/in/md-rokonuzzaman-tam...

# %%
urls = df['url']
urls.head()
# Out:
# 0    https://bd.linkedin.com/in/md-mahabubul-kabir-...
# 1    https://bd.linkedin.com/in/faysal-ahmed-prodip...
# 2     https://bd.linkedin.com/in/asif-arefin-53523b13a
# 3    https://bd.linkedin.com/in/md-abdul-ahad-emran...
# 4    https://bd.linkedin.com/in/md-rokonuzzaman-tam...
# Name: url, dtype: object

# %%
len(urls)
# Out:
# 179

# %%
urls.unique()
# Out:
# array(['https://bd.linkedin.com/in/md-mahabubul-kabir-roni-chowdhury-085b6113a',
#        'https://bd.linkedin.com/in/faysal-ahmed-prodip01687836378',
#        'https://bd.linkedin.com/in/asif-arefin-53523b13a',
#        'https://bd.linkedin.com/in/md-abdul-ahad-emran-18a3ba55',
#        'https://bd.linkedin.com/in/md-rokonuzzaman-tamal-567a048a',
#        'https://bd.linkedin.com/in/md-zobair-62b05292',
#        'https://bd.linkedin.com/in/nurani-jely-6084ba69',
#        'https://bd.linkedin.com/in/alamd-shah-082147104',
#        'https://bd.linkedin.com/in/shoel120',
#        'https://bd.linkedin.com/in/nazrul-islam-bangladish-95726a6b',
#        'https://bd.linkedin.com/in/engr-mosihur-rahman-mieb-40572785',
#        'https://bd.linkedin.com/in/nipbd',
#        'https://bd.linkedin.com/in/hasan-a-jahedi-a952a248',
#        'https://bd.linkedin.com/in/engr-md-ferdaus-jaman-56b44394',
#        'https://bd.linkedin.com/in/shamim-reza-ab079b147',
# ...

# %%
un_url = urls.unique()
len(un_url)
# Out:
# 59

# %%
un_url.to_csv('ttt.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7131999b5b05> in <module>()
# ----> 1 un_url.to_csv('ttt.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
df2 = pd.DataFrame(un_url)
df2
# Out:
#                                                     0
# 0   https://bd.linkedin.com/in/md-mahabubul-kabir-...
# 1   https://bd.linkedin.com/in/faysal-ahmed-prodip...
# 2    https://bd.linkedin.com/in/asif-arefin-53523b13a
# 3   https://bd.linkedin.com/in/md-abdul-ahad-emran...
# 4   https://bd.linkedin.com/in/md-rokonuzzaman-tam...
# 5       https://bd.linkedin.com/in/md-zobair-62b05292
# 6     https://bd.linkedin.com/in/nurani-jely-6084ba69
# 7     https://bd.linkedin.com/in/alamd-shah-082147104
# 8                 https://bd.linkedin.com/in/shoel120
# 9   https://bd.linkedin.com/in/nazrul-islam-bangla...
# 10  https://bd.linkedin.com/in/engr-mosihur-rahman...
# 11                   https://bd.linkedin.com/in/nipbd
# 12  https://bd.linkedin.com/in/hasan-a-jahedi-a952...
# 13  https://bd.linkedin.com/in/engr-md-ferdaus-jam...
# 14   https://bd.linkedin.com/in/shamim-reza-ab079b147
# 15                 https://bd.linkedin.com/in/0zahid0
# ...

# %%
df2.to_csv('ttt.csv',header=None)
